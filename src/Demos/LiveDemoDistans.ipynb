// %%
fun giveMeFive() = 5

fun giveMeEight() : Int {
    return 8
}

fun giveMeMore() = println("more");

println(giveMeFive())

fun giveMeMore2() = "more"

giveMeMore2()
// Out:
// 5
// more

// %%
fun area (h: Int, w: Int) = h*w

fun area2 (h: Int, w: Int) : Int { return h*w}

fun circumference (h: Int, w: Int) = 2*h+2*w

fun circumference2 (h: Int, w: Int) : Int { return 2*h+2*w}

println(area(5,3))

println(circumference2(5,3))
// Out:
// 15
// 16

// %%
val x = 5

var y = 2.4

var v = 2.4f

var z : Long = 1234

var z2 = 1234L

z+5*y
// Out:
// 1246.0

// %%
class testClass(var x:Int = 0, private var y: Int){
    private val z = x+y
    val z2 = z

    fun hej(){println("hej")}
    private fun hejd(){println("hejd")}
}

fun testFun(x : Int, y : Int, t: testClass) {
    t.x = 1
    println(x+y)
}

var t = testClass(4,5)
t.hej()

var x = 5
val y = 4
testFun(y = 5, x = 5, t)
t.x
// Out:
// hej
// 9
// 1
