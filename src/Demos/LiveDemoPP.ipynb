// %%
println("Hello World from NoteBook")

val i = 5
val g = 8

println(g)
i
// Out:
// Hello World from NoteBook
// 8
// 5

// %%
fun giveMeFive() = 5

fun addFiveTo( x: Int ) = 5+x

fun adder( x: Int, y: Int ) = x+y

fun giveMeHej() = "hej"

fun giveMeEightLong() : Int { return 8 }
fun addEightTo(x : Int) : Int { return 8+x }

println(giveMeHej())
println(giveMeFive() + giveMeEightLong())

adder(5,7)

addFiveTo(9)
// Out:
// hej
// 13
// 14

// %%
var x = 6
x = 7
